# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as ow
from pprint import pprint
import datetime
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
#         if len(cities)<100:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ## Perform API Calls

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
record_counter = 0
set_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 2 of set 0 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 3 of set 0 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 4 of set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 5 of set 0 | seydi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 6 of set 0 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 7 of set 0 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 8 of set 0 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 9 of set 0 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 10 of set 0 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 11 of set 0 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 12 of set 0 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 13 of set 0 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 14 of set 0 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 15 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 16 of set 0 | mazyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 17 of set 0 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 18 of set 0 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 19 of set 0 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 20 of set 0 | nieves
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 21 of set 0 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 22 of set 0 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 23 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 24 of set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 25 of set 0 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 26 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 27 of set 0 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 28 of set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 29 of set 0 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 30 of set 0 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 31 of set 0 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 32 of set 0 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 33 of set 0 | villa rica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 34 of set 0 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 35 of set 0 | ca mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 36 of set 0 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 37 of set 0 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 38 of set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 39 of set 0 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 40 of set 0 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 41 of set 0 | khambhat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 42 of set 0 | qostanay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 43 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 44 of set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 45 of set 0 | uto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 46 of set 0 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 47 of set 0 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 48 of set 0 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 49 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 50 of set 0 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 0 of set 1 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 1 of set 1 | lucapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 2 of set 1 | sosnovo-ozerskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 3 of set 1 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 4 of set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 5 of set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 6 of set 1 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 7 of set 1 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 8 of set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 9 of set 1 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 10 of set 1 | konstantinovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 11 of set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 12 of set 1 | sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 13 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 14 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 15 of set 1 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 16 of set 1 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 17 of set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 18 of set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 19 of set 1 | teculutan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 20 of set 1 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 21 of set 1 | sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 22 of set 1 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 23 of set 1 | itaquyry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 24 of set 1 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 25 of set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 26 of set 1 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 27 of set 1 | asyut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 28 of set 1 | guanica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 29 of set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 30 of set 1 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 31 of set 1 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 32 of set 1 | shitanjing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 33 of set 1 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 34 of set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 35 of set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 36 of set 1 | myaundzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 37 of set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 38 of set 1 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 39 of set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 40 of set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 41 of set 1 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 42 of set 1 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 43 of set 1 | eldikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 44 of set 1 | meyungs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 45 of set 1 | panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 46 of set 1 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 47 of set 1 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 48 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 49 of set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 50 of set 1 | uvira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 0 of set 2 | nigde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 1 of set 2 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 2 of set 2 | mackenzie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 3 of set 2 | mahadday weyne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 4 of set 2 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 5 of set 2 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 6 of set 2 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 7 of set 2 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 8 of set 2 | la seyne-sur-mer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 9 of set 2 | holt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 10 of set 2 | buon me thuot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 11 of set 2 | sovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 12 of set 2 | bac lieu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 13 of set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 14 of set 2 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 15 of set 2 | plouzane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 16 of set 2 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 17 of set 2 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 18 of set 2 | esqueda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 19 of set 2 | tahoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 20 of set 2 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 21 of set 2 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 22 of set 2 | doka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 23 of set 2 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 24 of set 2 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 25 of set 2 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 0 of set 11 | otukpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 1 of set 11 | kollo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 2 of set 11 | wladyslawowo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 3 of set 11 | tema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 4 of set 11 | dori
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 5 of set 11 | palu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 6 of set 11 | goundam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 7 of set 11 | zeulenroda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 8 of set 11 | conceicao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 9 of set 11 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 10 of set 11 | zlitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 11 of set 11 | englehart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 12 of set 11 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 13 of set 11 | marktredwitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 14 of set 11 | bundibugyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 15 of set 11 | bur gabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 16 of set 11 | viligili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 17 of set 11 | zeerust
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 18 of set 11 | sapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 19 of set 11 | xam nua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 20 of set 11 | bonfim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 21 of set 11 | kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 22 of set 11 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 23 of set 11 | kilindoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 24 of set 11 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 25 of set 11 | smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 26 of set 11 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 27 of set 11 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 28 of set 11 | ayna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 29 of set 11 | tingi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 30 of set 11 | bousso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# City not found!
# Processing record 31 of set 11 | novyy urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 32 of set 11 | santiago del estero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 33 of set 11 | dabakala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 34 of set 11 | barmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 35 of set 11 | boguchany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 36 of set 11 | alenquer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 37 of set 11 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 38 of set 11 | mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 39 of set 11 | moscow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 40 of set 11 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# Processing record 41 of set 11 | mae sai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f620fb30c60847c22331c6a34ade79d5
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          553
# Cloudiness    553
# Country       553
# Date          553
# Humidity      553
# Temp          553
# Lat           553
# Lng           553
# Wind Speed    553
# dtype: int64

# %%
weather_data.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Temp    Lat  \
# 0  verkhnevilyuysk          97      RU  1574516686        96   -9.26  63.45
# 1     ponta do sol          18      BR  1574516591        62   81.00 -20.63
# 2          fortuna           1      US  1574516557        93   45.00  40.60
# 3       bredasdorp          33      ZA  1574516549        70   70.00 -34.53
# 4            seydi           0      NE  1574516687        16  100.40  13.34
#
#       Lng  Wind Speed
# 0  120.31        4.94
# 1  -46.00        6.73
# 2 -124.16       12.75
# 3   20.04       13.00
# 4    7.75        9.17

# %%
cities_list = zip(new_cities,cloudiness,country,date,humidity,temp,lat,lng)
# Set variable for output file
output_file = os.path.join('..', 'output_data', 'cities.csv')
#  Open the output file
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)

# %%
date =datetime.datetime.fromtimestamp(
        int(weather_data['Date'][0])
    ).strftime('%m/%d/%Y')

# %%
# Latitude Vs Temperature Plot

weather_data.plot(kind='scatter', x='Lat', y='Temp', c='DarkBlue')
plt.title('City Latitude Vs Max Temperature ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsTemperature.png")

# %%
# Latitude Vs Humidity

weather_data.plot(kind='scatter',x='Lat',y='Humidity', c='DarkBlue')
plt.title('City Latitude Vs Max Humidity ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("../Images/LatitudeVsHumidity.png")

# %%
# Latitude Vs Cloudiness

weather_data.plot(kind='scatter',x='Lat',y='Cloudiness', c='DarkBlue')
plt.title('City Latitude Vs Cloudiness ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig("../Images/LatitudeVsCloudiness.png")

# %%
# Latitude Vs Wind Speed

weather_data.plot(kind='scatter',x='Lat',y='Wind Speed', c='DarkBlue')
plt.title('City Latitude Vs Wind Speed ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig("../Images/LatitudeVsWindSpeed.png")
